# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A=1
f=2
ph=0
sr=100

time=np.arange(0,10,1/sr)
y=A*np.sin(2*np.pi*f*time+ph)
#y=A*np.sin(time+ph)
plt.figure(figsize=(10,4))
plt.plot(time,y)
plt.title("sine wave")
plt.xlabel("time(s)")
plt.ylabel("amplitude")
plt.show()

# %%
A=1
f=2
ph=0
sr=100

time=np.arange(0,10,1/sr)
#y=A*np.tan(2*np.pi*f*time+ph)
y=A*np.tan(time+ph)
plt.figure(figsize=(10,4))
plt.plot(time,y)
plt.title("sine wave")
plt.xlabel("time(s)")
plt.ylabel("amplitude")
plt.show()

# %%
A=1
f=2
ph=180
sr=100

time=np.arange(0,10,1/sr)
#y=A*np.cos(2*np.pi*f*time+ph)
y=A*np.cos(time+ph)
plt.figure(figsize=(10,4))
plt.plot(time,y)
plt.title("cos wave")
plt.xlabel("time(s)")
plt.ylabel("amplitude")
plt.show()

# %%
A=1
f=2.5
ph=0
sr=100

time=np.arange(0,10,1/sr)
#y=A*np.arccos(2*np.pi*f*time+ph)
y=A*np.arccos(time+ph)
plt.figure(figsize=(10,4))
plt.plot(time,y)
plt.title("sec wave")
plt.xlabel("time(s)")
plt.ylabel("amplitude")
plt.show()
# Out:
# <ipython-input-62-dbb5d8685567>:8: RuntimeWarning: invalid value encountered in arccos
#   y=A*np.arccos(time+ph)

# %%
A=1
f=2
ph=0
sr=100

time=np.arange(0,10,1/sr)
#y=A*np.arcsin(2*np.pi*f*time+ph)
y=A*np.arcsin(time+ph)
plt.figure(figsize=(10,4))
plt.plot(time,y)
plt.title("cosec wave")
plt.xlabel("time(s)")
plt.ylabel("amplitude")
plt.show()
# Out:
# <ipython-input-63-d08de89b71e7>:8: RuntimeWarning: invalid value encountered in arcsin
#   y=A*np.arcsin(time+ph)

# %%
A=1
f=2
ph=0
sr=100

time=np.arange(0,10,1/sr)
#y=A*np.arctan(2*np.pi*f*time+ph)
y=A*np.arctan(time+ph)
plt.figure(figsize=(10,4))
plt.plot(time,y)
plt.title("cot wave")
plt.xlabel("time(s)")
plt.ylabel("amplitude")
plt.show()
